# %% [markdown]
# # 1
# x = 3 ----> floata çevirelim. Çevirdikten sonra beri tipinide yazdıralım.
#
# y = 4.5 -----> integere çevirelim. Çevirdikten sonra beri tipinide yazdıralım.
#
# z = "8" -----> integera çevirelim. Çevirdikten sonra beri tipinide yazdıralım.
#
# a = "12" -----> floata çevirelim. Çevirdikten sonra beri tipinide yazdıralım.
#
# b = "46.8" ------> integera çevirelim. Çevirdikten sonra beri tipinide yazdıralım.

# %%
x = float(3)
x
# Out:
# 3.0

# %%
type(x)
# Out:
# float

# %%
y = int(4.5)
y
# Out:
# 4

# %%
type(y)
# Out:
# int

# %%
z= "8"
int(z) #int("8")
# Out:
# 8

# %%
a = "12"
f=float(a)#float(int(a))
f
# Out:
# 12.0

# %%
type(f)
# Out:
# float

# %%
b = "46.8"
c =int(float(b))#sdc tam kısım alınıyor yuvarlama yapılmıyor
c
# Out:
# 46

# %%
type(c)
# Out:
# int

# %% [markdown]
# # 2
# İsimlerden oluşan üç değişkene yaş değerleri atanır. Belirlenen üç değişken birbiriyle karşılaştırma operatörleri ile karşılaştırılır. Bu karşılaştırmalara mantıksal operatörler de eklenir.

# %%
ayse=21
volkan=28
fatma=48
if ayse < volkan and ayse <fatma:
  print("ayse en küçük")
if fatma>ayse and fatma>volkan:
  print("fatma en büyük")
# Out:
# ayse en küçük
# fatma en büyük

# %%
not(volkan<ayse or ayse>fatma)
# Out:
# True

# %%
ayse < volkan and ayse <fatma
# Out:
# True

# %%
fatma!=volkan + ayse
# Out:
# True

# %% [markdown]
# # 3
# Kullanıcıdan iki değer girmesini istenir. Girilen değerlerin toplama, çıkarma, çarpma, bölme sonuçlarını yazdırılır.

# %%
number1=input("bir sayı giriniz: ")
number2= input("bir sayı daha giriniz:")
# Out:
# bir sayı giriniz: 54
# bir sayı daha giriniz:19

# %%
number1+number2
# Out:
# '5419'

# %%
int(number1)+int(number2)
# Out:
# 73

# %%
n1=int(number1)
n2=int(number2)
n1-n2
# Out:
# 35

# %%
n1*n2
# Out:
# 1026

# %%
n1/n2
# Out:
# 2.8421052631578947

# %%
n1//n2
# Out:
# 2

# %%
n1%n2
# Out:
# 16

# %% [markdown]
# # 4
# Kullanıcıdan isim, yaş, şehir ve meslek bilgilerini istenir ve cevaplarını yazdırılır.

# %%
ad=input("adınız:" )#"" unutma
yaş=int(input("yaşınız: "))
il=input("yaşadığınız şehir: ")
meslek=input("mesleğiniz: ")
print(f"merhaba sizin adınız {ad} ,yaşınız {yaş} ,yaşadığınız il {il} ve mesleğiniz {meslek} doğru mu bir karışıklık yok değil mi?")
cevap=input("bilgiler doğru mu(yes/no): ")
if cevap=="yes":
  print("doğru kişisiniz buna çok sevindim.")
else:
  print("üzgünüm yanlış kişi ile görüşüyorum kusura bakmayın.")
# Out:
# adınız:hatice
# yaşınız: 23
# yaşadığınız şehir: istanbul
# mesleğiniz: öğrenci
# merhaba sizin adınız hatice ,yaşınız 23 ,yaşadığınız il istanbul ve mesleğiniz öğrenci doğru mu bir karışıklık yok değil mi?
# bilgiler doğru mu(yes/no): evet
# üzgünüm yanlış kişi ile görüşüyorum kusura bakmayın.

# %% [markdown]
# # 5
# "Hi-Kod Veri Bilimi Atölyesi" ifadesini bir değişkene tanımlanır.
#
#
#  1. İfadedeki her bir kelimeyi ("Hi-Kod", "Veri", "Bilimi", "Atölyesi") değişken içinden seçilir.
#  2. İfadeyi hepsini büyük harf olacak hale çevrilir. ("HI-KOD VERİ BİLİMİ ATÖLYESİ")
#  3. İfadeyi hepsini büyük harf olacak hale çevrilir.("hi-kod veri bilimi atölyesi")
#
# "0123456789" ifadesindeki yalnızca çift sayıları ve yalnızca tek sayıları seçilir. ("02468", "13579")

# %%
education="Hi-Kod Veri Bilimi Atölyesi"
print(education.split())
# Out:
# ['Hi-Kod', 'Veri', 'Bilimi', 'Atölyesi']

# %%
print(education.upper())#tüm ifade büyük harf olur
# Out:
# HI-KOD VERI BILIMI ATÖLYESI

# %%
print(education.lower())#tüm ifade küçük harf olur
# Out:
# hi-kod veri bilimi atölyesi

# %%
sayi=("0123456789")
sayi
# Out:
# '0123456789'

# %%
len(sayi)
# Out:
# 10

# %%
#bu soru alg iyi
even=""
odd =""
for i in sayi:
  if int(i)%2==0:
    even +=i
  else:
    odd +=i
print(even)
print(odd)
# Out:
# 02468
# 13579
