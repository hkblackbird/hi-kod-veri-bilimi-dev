# %% [markdown]
# <a href="https://colab.research.google.com/github/hkblackbird/hi-kod-veri-bilimi-dev/blob/main/Kosul_dongu_odev.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Ödev-1:** Kullanıcıdan maaş bilgisini istenir ve bu bilgiye göre maaşından ne kadar vergi kesileceğini hesaplanır. Kullanıcının geliri;
#
# 1. 10000 ve altındaysa maaşından %5 kesinti olur.
# 2. 25000 ve altındaysa maaşından %10 kesinti olur.
# 3. 45000 ve altındaysa maaşından %25 kesinti olur.
# 4. Diğer koşullarda %30 kesinti olur.
#
# Bu durumlara göre kullanıcının yeni maaşı yazdırılır.

# %%
maas=int(input("Maaşınızı giriniz: "))
if maas<=10000:
  kesinti=maas*0.005
  maas=maas-kesinti
  print(f"net maaş: {maas}")
elif (maas<=25000):
  kesinti=maas*0.01
  maas-=kesinti
  print(f"net maaş: {maas}")
elif(maas<=45000):
  kesinti=maas*0.25
  maas-=kesinti
  print(f"net maaş: {maas}")
else:
  kesinti=maas*0.3
  maas-=kesinti
  print(f"net maaş: {maas}")
# Out:
# Maaşınızı giriniz: 46000
# net maaş: 32200.0

# %% [markdown]
# **Ödev-2:** Kullanıcıdan kullanıcı adı ve şifre oluşturmasını istenir. Şifrenin uzunluğu altı haneye ulaşmışsa hesabınız oluşturuldu mesajı alınır, altı haneden azsa altı haneli şifre oluşturması gerektiğinin mesajı alınır. *(Sadece koşul kullanılması yeterli.)*

# %%
kullanıcı_ad=input("kullanıcı adını giriniz: ")
sifre=input("şifrenizi giriniz: ")
if len(sifre)!=6:
  print("şifreniz 6 haneli olmalıdır lütfen yeni şifre oluşturun!")
else:
  print("hesabınız oluşturuldu.")
# Out:
# kullanıcı adını giriniz: hatice
# şifrenizi giriniz: 123
# şifreniz 6 haneli olmalıdır lütfen yeni şifre oluşturun!

# %% [markdown]
# **Ödev-3:** Bir önceki örnek geliştirilir.
#
# 1. Kullanıcı girdiği şifre 5 ve 10 hane arasında olmak zorunda.
# 2. Eğer bu koşula uyuyorsa "Hesabınız oluşturuldu." mesajı alır.
# 3. Koşulu sağlamıyorsa "Lütfen girdiniz şifre 5 haneden az 10 haneden fazla olmasın!" uyarısı alır.
# 4. Bunu oluştururken kullanıcı istediğimiz şartlarda şifre oluşturana kadar sormaya devam eder

# %%
#******************
kullanıcı_ad=input("kullanıcı adını giriniz: ")
sifre=input("şifrenizi giriniz: ")

while not(len(sifre)>=5 and len(sifre)<= 10):
  print("lütfen girdiğiniz şifre 5 haneden az veya 10 haneden fazla olmasın!")
  sifre=input("lütfen yeni sifre giriniz: ")
print("hesabınız oluşturuldu.")
# Out:
# kullanıcı adını giriniz: hativce
# şifrenizi giriniz: 123
# Lütfen girdiğiniz şifre 5 haneden az veya 10 haneden fazla olmasın!
# Lütfen yeni şifre giriniz: 12
# Lütfen girdiğiniz şifre 5 haneden az veya 10 haneden fazla olmasın!
# Lütfen yeni şifre giriniz: 122
# Lütfen girdiğiniz şifre 5 haneden az veya 10 haneden fazla olmasın!
# Lütfen yeni şifre giriniz: 123581
# Hesabınız oluşturuldu.

# %% [markdown]
# **Ödev-4:** Kullanıcıdan isim ve şifre isteyeceğiz ve şifre girişi için üç hak verilir.
#
# 1. Eğer önceden tanımlı şifre ile kullanıcıdan gelen şifre aynıysa "Giriş yapıldı." yazar.
# 2. Şifre girişi yanlışsa "Yanlış şifre girildi!" uyarısı verilsin ve üç yanlış denemede program biter.
# 3. Tercihe göre kalan hak bilgisi verilir.

# %%
kullanıcı_ad=input("kullanıcı adını giriniz: ")
sifre_asıl="123456"
deneme_hakkı=3
while deneme_hakkı>0:
  girilen_sifre=input("şifrenizi giriniz: ")
  if girilen_sifre==sifre_asıl:
    print("giriş yapıldı")
  else:
    deneme_hakkı-=1
    print(f"yanlış şifre girdiniz kalan deneme hakkı: {deneme_hakkı}")
    if deneme_hakkı==0:
      print("deneme hakkınız bitti")
